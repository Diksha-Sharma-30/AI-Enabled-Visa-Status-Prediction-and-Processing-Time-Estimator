# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url= "https://raw.githubusercontent.com/gunjan975/Visa-Status-Prediction/main/dataset.csv"
df=pd.read_csv(url)
df
# Out:
#             CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0    I-200-19268-393467   Certified    2019-09-25    2019-10-01
# 1    I-200-19268-638983   Certified    2019-09-25    2019-10-01
# 2    I-200-19268-177184   Certified    2019-09-25    2019-10-01
# 3    I-200-19268-936403   Certified    2019-09-25    2019-10-01
# 4    I-200-19268-394079   Certified    2019-09-25    2019-10-01
# ..                  ...         ...           ...           ...
# 193  I-200-19268-117570   Certified    2019-09-25    2019-10-01
# 194  I-200-19268-716774   Certified    2019-09-25    2019-10-01
# 195  I-200-19267-663335   Certified    2019-09-25    2019-10-01
# 196  I-200-19268-961330   Certified    2019-09-25    2019-10-01
# 197  I-200-19267-585164   Certified    2019-09-25    2019-10-01
#
#      ORIGINAL_CERT_DATE VISA_CLASS                               JOB_TITLE  \
# 0                   NaN       H-1B  APPLICATION ENGINEER, OMS [15-1199.02]
# ...

# %%
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (198, 96)
#           CASE_NUMBER CASE_STATUS RECEIVED_DATE DECISION_DATE  \
# 0  I-200-19268-393467   Certified    2019-09-25    2019-10-01
# 1  I-200-19268-638983   Certified    2019-09-25    2019-10-01
# 2  I-200-19268-177184   Certified    2019-09-25    2019-10-01
# 3  I-200-19268-936403   Certified    2019-09-25    2019-10-01
# 4  I-200-19268-394079   Certified    2019-09-25    2019-10-01
#
#    ORIGINAL_CERT_DATE VISA_CLASS                               JOB_TITLE  \
# 0                 NaN       H-1B  APPLICATION ENGINEER, OMS [15-1199.02]
# 1                 NaN       H-1B                         BI DEVELOPER II
# 2                 NaN       H-1B                        QUALITY ENGINEER
# 3                 NaN       H-1B        SOFTWARE DEVELOPER, APPLICATIONS
# 4                 NaN       H-1B               QUALITY ENGINEER LEVEL II
#
#   SOC_CODE                          SOC_TITLE FULL_TIME_POSITION  ...  \
# ...

# %%
print(df.isnull().sum())
# Out:
# CASE_NUMBER                  0
# CASE_STATUS                  0
# RECEIVED_DATE                0
# DECISION_DATE                0
# ORIGINAL_CERT_DATE         198
#                           ...
# PREPARER_LAST_NAME          85
# PREPARER_FIRST_NAME         85
# PREPARER_MIDDLE_INITIAL    169
# PREPARER_BUSINESS_NAME      85
# PREPARER_EMAIL              72
# Length: 96, dtype: int64

# %%
num_cols = df.select_dtypes(include=np.number).columns
cat_cols = df.select_dtypes(include='object').columns

df[num_cols] = df[num_cols].fillna(df[num_cols].median())
df[cat_cols] = df[cat_cols].apply(lambda x: x.fillna(x.mode()[0]))

print("\nMissing Values After:\n")
print(df.isnull().sum())
# Out:
# Missing Values After:
#
# CASE_NUMBER                  0
# CASE_STATUS                  0
# RECEIVED_DATE                0
# DECISION_DATE                0
# ORIGINAL_CERT_DATE         198
#                           ...
# PREPARER_LAST_NAME           0
# PREPARER_FIRST_NAME          0
# PREPARER_MIDDLE_INITIAL      0
# PREPARER_BUSINESS_NAME       0
# PREPARER_EMAIL               0
# Length: 96, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['CASE_NUMBER', 'CASE_STATUS', 'RECEIVED_DATE', 'DECISION_DATE',
#        'ORIGINAL_CERT_DATE', 'VISA_CLASS', 'JOB_TITLE', 'SOC_CODE',
#        'SOC_TITLE', 'FULL_TIME_POSITION', 'BEGIN_DATE', 'END_DATE',
#        'TOTAL_WORKER_POSITIONS', 'NEW_EMPLOYMENT', 'CONTINUED_EMPLOYMENT',
#        'CHANGE_PREVIOUS_EMPLOYMENT', 'NEW_CONCURRENT_EMPLOYMENT',
#        'CHANGE_EMPLOYER', 'AMENDED_PETITION', 'EMPLOYER_NAME',
#        'TRADE_NAME_DBA', 'EMPLOYER_ADDRESS1', 'EMPLOYER_ADDRESS2',
#        'EMPLOYER_CITY', 'EMPLOYER_STATE', 'EMPLOYER_POSTAL_CODE',
#        'EMPLOYER_COUNTRY', 'EMPLOYER_PROVINCE', 'EMPLOYER_PHONE',
#        'EMPLOYER_PHONE_EXT', 'NAICS_CODE', 'EMPLOYER_POC_LAST_NAME',
#        'EMPLOYER_POC_FIRST_NAME', 'EMPLOYER_POC_MIDDLE_NAME',
#        'EMPLOYER_POC_JOB_TITLE', 'EMPLOYER_POC_ADDRESS1',
#        'EMPLOYER_POC_ADDRESS2', 'EMPLOYER_POC_CITY', 'EMPLOYER_POC_STATE',
#        'EMPLOYER_POC_POSTAL_CODE', 'EMPLOYER_POC_COUNTRY',
# ...

# %%
df['RECEIVED_DATE'] = pd.to_datetime(df['RECEIVED_DATE'], errors='coerce')
df['DECISION_DATE'] = pd.to_datetime(df['DECISION_DATE'], errors='coerce')

# %%
print(df[['RECEIVED_DATE', 'DECISION_DATE']].dtypes)
# Out:
# RECEIVED_DATE    datetime64[ns]
# DECISION_DATE    datetime64[ns]
# dtype: object

# %%
df['processing_time_days'] = (df['DECISION_DATE'] - df['RECEIVED_DATE']).dt.days

# %%
df[['RECEIVED_DATE', 'DECISION_DATE', 'processing_time_days']]
# Out:
#     RECEIVED_DATE DECISION_DATE  processing_time_days
# 0      2019-09-25    2019-10-01                     6
# 1      2019-09-25    2019-10-01                     6
# 2      2019-09-25    2019-10-01                     6
# 3      2019-09-25    2019-10-01                     6
# 4      2019-09-25    2019-10-01                     6
# ..            ...           ...                   ...
# 193    2019-09-25    2019-10-01                     6
# 194    2019-09-25    2019-10-01                     6
# 195    2019-09-25    2019-10-01                     6
# 196    2019-09-25    2019-10-01                     6
# 197    2019-09-25    2019-10-01                     6
#
# [198 rows x 3 columns]

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['processing_time_days'], bins=30, kde=True)
plt.title('Distribution of Processing Time (Days)')
plt.xlabel('Processing Time (Days)')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(10,6))
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
